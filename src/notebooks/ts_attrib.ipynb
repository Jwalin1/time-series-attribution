# %%
import os
from google.colab import drive
drive.mount("/content/drive")
os.chdir("/content/drive/MyDrive/project")

# %%
# %run scripts/main.py  --dataset "FordA" \
                      --epochs 10
# Out:
# device: cpu
# downloading file  http://www.timeseriesclassification.com/Downloads/FordA.zip
# file already exists
# zip already extracted
# params: 23861058
# training model
# ...
# epoch: 1  | train loss: 0.6963, val loss: 0.6870,
# ...
# epoch: 2  | train loss: 0.5776, val loss: 0.4040,
# ...
# epoch: 3  | train loss: 0.2940, val loss: 0.2803,
# ...
# epoch: 4  | train loss: 0.3000, val loss: 0.2791,
# ...
# epoch: 5  | train loss: 0.2539, val loss: 0.2254,
# ...
# epoch: 6  | train loss: 0.1975, val loss: 0.2577,
# ...
# epoch: 7  | train loss: 0.1960, val loss: 0.2117,
# ...
# epoch: 8  | train loss: 0.2650, val loss: 0.2464,
# ...
# epoch: 9  | train loss: 0.1962, val loss: 0.2207,
# ...
# epoch: 10  | train loss: 0.1939, val loss: 0.1982,
# Finished Training
# ...
#               precision    recall  f1-score   support
#
#          0.0     0.9493    0.9339    0.9415       681
#          1.0     0.9308    0.9468    0.9387       639
#
#     accuracy                         0.9402      1320
# ...
