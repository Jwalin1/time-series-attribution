# %%
import os
from google.colab import drive
drive.mount("/content/drive")
os.chdir("/content/drive/MyDrive/project")
# Out:
# Mounted at /content/drive

# %%
# %run scripts/main.py  --dataset "Cricket" \
                      --epochs 100
# Out:
# device: cpu
# device: cpu
# downloading file  http://www.timeseriesclassification.com/Downloads/Cricket.zip
# file already exists
# zip already extracted
# train_inputs shape: (108, 6, 1197)
# params: 23905548
# training model
# ...
# epoch: 10  | train loss: 0.5390, val loss: 0.4082,  | avg train loss: 1.6021, avg val loss: 1.6796,
# ...
# epoch: 20  | train loss: 0.3400, val loss: 1.1455,  | avg train loss: 0.3145, avg val loss: 0.2995,
# ...
# epoch: 30  | train loss: 0.0262, val loss: 0.0419,  | avg train loss: 0.2465, avg val loss: 0.1521,
# ...
# epoch: 40  | train loss: 0.0173, val loss: 0.0016,  | avg train loss: 0.0231, avg val loss: 0.0073,
# ...
# epoch: 50  | train loss: 0.0029, val loss: 0.0012,  | avg train loss: 0.0071, avg val loss: 0.0013,
# ...
# epoch: 60  | train loss: 0.0029, val loss: 0.0017,  | avg train loss: 0.0082, avg val loss: 0.0014,
# Stopping Early
# Finished Training
# ...
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000         6
# ...
