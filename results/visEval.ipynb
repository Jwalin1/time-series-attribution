# %%
# !pip install captum

# %%
import os
os.chdir("/content/time-series-attribution/src/notebooks")

# %run ../scripts/main.py  --visEvalParams '{"datasets":["CharacterTrajectories", "SyntheticAnomaly"], \
                                           "rand_layers":["1","2"], \
                                           "methods":["Saliency", "LayerGradCam"], \
                                           "approaches":["replaceWithMean", "replaceWithInterp"] \
                                          }'
# Out:
# device: cpu
# dataset:CharacterTrajectories, rand_layer:1, method:Saliency, approach:replaceWithMean
# dataset:CharacterTrajectories, rand_layer:1, method:Saliency, approach:replaceWithInterp
# dataset:CharacterTrajectories, rand_layer:1, method:LayerGradCam, approach:replaceWithMean
# dataset:CharacterTrajectories, rand_layer:1, method:LayerGradCam, approach:replaceWithInterp
# dataset:CharacterTrajectories, rand_layer:2, method:Saliency, approach:replaceWithMean
# dataset:CharacterTrajectories, rand_layer:2, method:Saliency, approach:replaceWithInterp
# dataset:CharacterTrajectories, rand_layer:2, method:LayerGradCam, approach:replaceWithMean
# dataset:CharacterTrajectories, rand_layer:2, method:LayerGradCam, approach:replaceWithInterp
# dataset:SyntheticAnomaly, rand_layer:1, method:Saliency, approach:replaceWithMean
# dataset:SyntheticAnomaly, rand_layer:1, method:Saliency, approach:replaceWithInterp
# ...
