# %%
# !pip install captum

# %%
import os
os.chdir("/content/time-series-attribution/src/notebooks")

# %run ../scripts/main.py  --visEvalParams '{"dataset":"CharacterTrajectories", \
                                            "method":"Saliency", \
                                            "approach":"replaceWithMean",  \
                                            "perc":None,  \
                                            "rand_layer":None, \
                                            }'  \
                         --load True  \
# Out:
# device: cpu
