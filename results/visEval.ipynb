# %%
# !pip install captum

# %%
import os
os.chdir("/content/time-series-attribution/src/notebooks")

# %run ../scripts/main.py  --visEvalParams '{"dataset":"SyntheticAnomaly", \
                                            "rand_layer":"0", \
                                            "method":"Saliency", \
                                            "approach":None,  \
                                            "perc":None,  \
                                            }'  \
                         --load True  \
# Out:
# device: cpu
